# %% [markdown]
# <a href="https://colab.research.google.com/github/HillaAnku/HillaAnku/blob/master/cont_vars_exploration_credit_risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Continous Variables Processing And Selection**
#
# This notebook takes a walk through the processing, analysis and selection of continous variables for the credit risk model of the lending club dataset. There are about 2.2M+ records in this dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import StandardScaler

# %%
# load dataset

lendingclub_df = pd.read_csv('/content/drive/My Drive/python_for_data_scientists/lendingclub.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# display all the columns of the dataset

pd.options.display.max_columns = None

# %% [markdown]
# I try to separate continous and categorical variables into two different dataframes which will be analyzed separately. The variables selected subsequently will be used in building the credit model.

# %%
# Make a list of continius variables

cont_vars = []
for column_name in lendingclub_df.columns:
    if lendingclub_df[column_name].dtype != 'object':
        cont_vars.append(column_name)

# %%
# Make a list of categorical variables

cat_vars = []
for column_name in lendingclub_df.columns:
    if lendingclub_df[column_name].dtype == 'object':
        cat_vars.append(column_name)

# %%
cat_vars
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'earliest_cr_line',
#  'initial_list_status',
#  'last_pymnt_d',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'application_type',
#  'verification_status_joint',
#  'sec_app_earliest_cr_line',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_loan_status',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date']

# %%
# Create a dataframe of continous variables only

cont_vars_df = lendingclub_df[cont_vars]

# %%
# Create a dataframe of categorical variables only

cat_vars_df = lendingclub_df[cat_vars]

# %% [markdown]
# Loan status is the target variable for the credit risk model. It appears in the dataset as a categorical variable with 9 distinct string descritions that describe the status of a loan. Loan status is added to continous variables to be processed and analyzed in terms of its relationship with the continous variables that will later be used as loan status predictors in the risk model.

# %%
# Add in the target variable loan status

cont_vars_df = pd.concat([cont_vars_df, lendingclub_df['loan_status']], axis = 1)

# %% [markdown]
# emp-length, issue-d, earliest-cr-line and term are supposed to be continous variables in the data. But they were recorded in the data as categorical variables. They are also added into the continous variables dataframe for processing and analysis.

# %%
# Add emp_length to contnous variables

cont_vars_df = pd.concat([cont_vars_df, lendingclub_df['emp_length']], axis = 1)

# %%
# Add issue_d to continous variables

cont_vars_df = pd.concat([cont_vars_df, lendingclub_df['issue_d']], axis = 1)

# %%
# Add earliest_cr_line to continous variables

cont_vars_df = pd.concat([cont_vars_df, lendingclub_df['earliest_cr_line']], axis = 1)

# %%
# Add term to continous variables

cont_vars_df = pd.concat([cont_vars_df, lendingclub_df['term']], axis = 1)

# %%
cont_vars_df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0 NaN        NaN       2500         2500           2500.0     13.56
# 1 NaN        NaN      30000        30000          30000.0     18.94
# 2 NaN        NaN       5000         5000           5000.0     17.97
# 3 NaN        NaN       4000         4000           4000.0     18.94
# 4 NaN        NaN      30000        30000          30000.0     16.14
#
#    installment  annual_inc  url    dti  delinq_2yrs  inq_last_6mths  \
# 0        84.92     55000.0  NaN  18.24          0.0             1.0
# 1       777.23     90000.0  NaN  26.52          0.0             0.0
# 2       180.69     59280.0  NaN  10.51          0.0             0.0
# 3       146.51     92000.0  NaN  16.74          0.0             0.0
# 4       731.78     57250.0  NaN  26.35          0.0             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                    45.0       9.0      1.0
# 1                    71.0                    75.0      13.0      1.0
# 2                     NaN                     NaN       8.0      0.0
# 3                     NaN                     NaN      10.0      0.0
# 4                     NaN                     NaN      12.0      0.0
#
#    revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
#
0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0           100.0
# 1           0.0                 0.0                 6.0            95.0
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 3.0           100.0
# 4           0.0                 0.0                 5.0            92.3
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   1.0        0.0          60124.0
# 1               0.0                   1.0        0.0         372872.0
# 2               0.0                   0.0        0.0         136927.0
# 3             100.0                   0.0        0.0         385183.0
# 4               0.0                   0.0        0.0         157548.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            16901.0         36500.0                     18124.0
# 1            99468.0         15000.0                     94072.0
# 2            11749.0         13800.0                     10000.0
# 3            36151.0          5000.0                     44984.0
# 4            29674.0          9300.0                     32332.0
#
#    revol_bal_joint  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0              NaN                     NaN               NaN
# 1              NaN                     NaN               NaN
# 2              NaN                     NaN               NaN
# 3              NaN                     NaN               NaN
# 4              NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# 0            NaN              NaN              NaN           NaN
# 1            NaN              NaN              NaN           NaN
# 2            NaN              NaN              NaN           NaN
# 3            NaN              NaN              NaN           NaN
# 4            NaN              NaN              NaN           NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount  settlement_amount  settlement_percentage  \
# 0                           NaN                NaN                    NaN
# 1                           NaN                NaN                    NaN
# 2                           NaN                NaN                    NaN
# 3                           NaN                NaN                    NaN
# 4                           NaN                NaN                    NaN
#
#    settlement_term loan_status emp_length   issue_d earliest_cr_line  \
# 0              NaN     Current  10+ years  Dec-2018         Apr-2001
# 1              NaN     Current  10+ years  Dec-2018         Jun-1987
# 2              NaN     Current    6 years  Dec-2018         Apr-2011
# 3              NaN     Current  10+ years  Dec-2018         Feb-2006
# 4              NaN     Current  10+ years  Dec-2018         Dec-2000
#
#          term
# 0   36 months
# 1   60 months
# 2   36 months
# 3   36 months
# 4   60 months

# %% [markdown]
# To avoid kernel crushing issues, I take a sample of 200000 of the 2M+ instances for processing and subsequent analysis. All records will be used in the modeling stage.

# %%
# Take a sample of the data

cont_sample = cont_vars_df.sample(200000)

# %%
cont_sample.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 2181401 to 1818638
# Data columns (total 114 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   id                                          0 non-null       float64
#  1   member_id                                   0 non-null       float64
#  2   loan_amnt                                   200000 non-null  int64
#  3   funded_amnt                                 200000 non-null  int64
#  4   funded_amnt_inv                             200000 non-null  float64
#  5   int_rate                                    200000 non-null  float64
#  6   installment                                 200000 non-null  float64
#  7   annual_inc                                  200000 non-null  float64
#  8   url                                         0 non-null       float64
#  9   dti                                         199879 non-null  float64
#  10  delinq_2yrs                                 199996 non-null  float64
#  11  inq_last_6mths                              199996 non-null  float64
#  12  mths_since_last_delinq                      97433 non-null   float64
#  13  mths_since_last_record                      31769 non-null   float64
#  14  open_acc                                    199996 non-null  float64
#  15  pub_rec                                     199996 non-null  float64
#  16  revol_bal                                   200000 non-null  int64
#  17  revol_util                                  199842 non-null  float64
#  18  total_acc                                   199996 non-null  float64
#  19  out_prncp                                   200000 non-null  float64
#  20  out_prncp_inv                               200000 non-null  float64
#  21  total_pymnt                                 200000 non-null  float64
#  22  total_pymnt_inv                             200000 non-null  float64
#  23  total_rec_prncp                             200000 non-null  float64
#  24  total_rec_int                               200000 non-null  float64
#  25  total_rec_late_fee                          200000 non-null  float64
#  26  recoveries                                  200000 non-null  float64
#  27  collection_recovery_fee                     200000 non-null  float64
#  28  last_pymnt_amnt                             200000 non-null  float64
#  29  collections_12_mths_ex_med                  199986 non-null  float64
#  30  mths_since_last_major_derog                 51436 non-null   float64
#  31  policy_code                                 200000 non-null  int64
#  32  annual_inc_joint                            10695 non-null   float64
#  33  dti_joint                                   10694 non-null   float64
#  34  acc_now_delinq                              199996 non-null  float64
#  35  tot_coll_amt                                193979 non-null  float64
#  36  tot_cur_bal                                 193979 non-null  float64
#  37  open_acc_6m                                 123547 non-null  float64
#  38  open_act_il                                 123547 non-null  float64
#  39  open_il_12m                                 123547 non-null  float64
#  40  open_il_24m                                 123547 non-null  float64
#  41  mths_since_rcnt_il                          119618 non-null  float64
#  42  total_bal_il                                123547 non-null  float64
#  43  il_util                                     105554 non-null  float64
#  44  open_rv_12m                                 123547 non-null  float64
#  45  open_rv_24m                                 123547 non-null  float64
#  46  max_bal_bc                                  123547 non-null  float64
#  47  all_util                                    123525 non-null  float64
#  48  total_rev_hi_lim                            193979 non-null  float64
#  49  inq_fi                                      123547 non-null  float64
#  50  total_cu_tl                                 123547 non-null  float64
#  51  inq_last_12m                                123547 non-null  float64
#  52  acc_open_past_24mths                        195689 non-null  float64
#  53  avg_cur_bal                                 193972 non-null  float64
#  54  bc_open_to_buy                              193472 non-null  float64
#  55  bc_util                                     193369 non-null  float64
#  56  chargeoff_within_12_mths                    199986 non-null  float64
#  57  delinq_amnt                                 199996 non-null  float64
#  58  mo_sin_old_il_acct                          187859 non-null  float64
#  59  mo_sin_old_rev_tl_op                        193979 non-null  float64
#  60  mo_sin_rcnt_rev_tl_op                       193979 non-null  float64
#  61  mo_sin_rcnt_tl                              193979 non-null  float64
#  62  mort_acc                                    195689 non-null  float64
#  63  mths_since_recent_bc                        193629 non-null  float64
#  64  mths_since_recent_bc_dlq                    45942 non-null   float64
#  65  mths_since_recent_inq                       174036 non-null  float64
#  66  mths_since_recent_revol_delinq              65356 non-null   float64
#  67  num_accts_ever_120_pd                       193979 non-null  float64
#  68  num_actv_bc_tl                              193979 non-null  float64
#  69  num_actv_rev_tl                             193979 non-null  float64
#  70  num_bc_sats                                 194974 non-null  float64
#  71  num_bc_tl                                   193979 non-null  float64
#  72  num_il_tl                                   193979 non-null  float64
#  73  num_op_rev_tl                               193979 non-null  float64
#  74  num_rev_accts                               193979 non-null  float64
#  75  num_rev_tl_bal_gt_0                         193979 non-null  float64
#  76  num_sats                                    194974 non-null  float64
#  77  num_tl_120dpd_2m                            186538 non-null  float64
#  78  num_tl_30dpd                                193979 non-null  float64
#  79  num_tl_90g_dpd_24m                          193979 non-null  float64
#  80  num_tl_op_past_12m                          193979 non-null  float64
#  81  pct_tl_nvr_dlq                              193968 non-null  float64
#  82  percent_bc_gt_75                            193431 non-null  float64
#  83  pub_rec_bankruptcies                        199886 non-null  float64
#  84  tax_liens                                   199988 non-null  float64
#  85  tot_hi_cred_lim                             193979 non-null  float64
#  86  total_bal_ex_mort                           195689 non-null  float64
#  87  total_bc_limit                              195689 non-null  float64
#  88  total_il_high_credit_limit                  193979 non-null  float64
#  89  revol_bal_joint                             9565 non-null    float64
#  90  sec_app_inq_last_6mths                      9566 non-null    float64
#  91  sec_app_mort_acc                            9566 non-null    float64
#  92  sec_app_open_acc                            9566 non-null    float64
#  93  sec_app_revol_util                          9410 non-null    float64
#  94  sec_app_open_act_il                         9566 non-null    float64
#  95  sec_app_num_rev_accts                       9566 non-null    float64
#  96  sec_app_chargeoff_within_12_mths            9566 non-null    float64
#  97  sec_app_collections_12_mths_ex_med          9566 non-null    float64
#  98  sec_app_mths_since_last_major_derog         3195 non-null    float64
#  99  deferral_term                               940 non-null     float64
#  100 hardship_amount                             940 non-null     float64
#  101 hardship_length                             940 non-null     float64
#  102 hardship_dpd                                940 non-null     float64
#  103 orig_projected_additional_accrued_interest  747 non-null     float64
#  104 hardship_payoff_balance_amount              940 non-null     float64
#  105 hardship_last_payment_amount                940 non-null     float64
#  106 settlement_amount                           2976 non-null    float64
#  107 settlement_percentage                       2976 non-null    float64
#  108 settlement_term                             2976 non-null    float64
#  109 loan_status                                 200000 non-null  object
#  110 emp_length                                  187035 non-null  object
#  111 issue_d                                     200000 non-null  object
#  112 earliest_cr_line                            199996 non-null  object
#  113 term                                        200000 non-null  object
# dtypes: float64(105), int64(4), object(5)
# memory usage: 175.5+ MB

# %% [markdown]
# In the following lines, I process all the categorical variables that are supposed to be continous variables by cleaning them up, removing unwanted characters, renaming and changing their dtypes accordingly.

# %%
# Strip unwanted string characers from emp_length column

cont_sample['emp_length_int'] = cont_sample['emp_length'].str.replace(' years', '')
cont_sample['emp_length_int'] = cont_sample['emp_length_int'].str.replace('< 1 year', str(0))
cont_sample['emp_length_int'] = cont_sample['emp_length_int'].str.replace('1 year', str(1))
cont_sample['emp_length_int'] = cont_sample['emp_length_int'].str.replace('10\+', '10')

# %%
# convert emp_length_int(categorical) to numerical data

cont_sample['emp_length_int'] = pd.to_numeric(cont_sample['emp_length_int'])

# %%
# Strip unwanted string characters from the 'term' variable

cont_sample['term_int'] = cont_sample['term'].str.replace(' ', '')
cont_sample['term_int'] = cont_sample['term_int'].str.replace('months', '')

# %%
# convert the categorical 'term_int' variable to a numerical one

cont_sample['term_int'] = pd.to_numeric(cont_sample['term_int'])

# %%
# Do the same for the issue_d (date loan was issued), convert the column to a date type

cont_sample['_since_issue_d'] = pd.to_datetime(cont_sample['issue_d'])

# %%
# Issue_d is a date type, convert to date type

cont_sample['mths_since_loan_issue'] = round(pd.to_numeric((pd.to_datetime('2020-04-18') - cont_sample['_since_issue_d'])/np.timedelta64(1, 'M')))

# %%
# earliest_cr_line is stored as a string but it should be a date type. Convert it to date type

cont_sample['tm_of_earliestcr'] = pd.to_datetime(cont_sample['earliest_cr_line'])

# %%
# Instead of showing the date time in days, convert to number of months

cont_sample['mths_since_earliest_cr'] = round(pd.to_numeric((pd.to_datetime('2019-03-18') - cont_sample['tm_of_earliestcr'])/np.timedelta64(1, 'M')))

# %%
# Drop the original categorical vriables and keep their numerical versions only

cont_sample = cont_sample.drop(['emp_length', 'issue_d', 'earliest_cr_line', 'term', '_since_issue_d', 'tm_of_earliestcr'], axis = 1)

# %% [markdown]
# At this point, all variables are numerical except loan status which will be taken care of later in the analysis. I, therefore, proceed to analyze the variables for relatonships with the target variable.

# %%
pd.set_option('display.max_rows', None)

# %%
# check for missing values

cont_sample.isnull().sum()*100/cont_sample.isnull().count()
# Out:
# id                                            100.0000
# member_id                                     100.0000
# loan_amnt                                       0.0000
# funded_amnt                                     0.0000
# funded_amnt_inv                                 0.0000
# int_rate                                        0.0000
# installment                                     0.0000
# annual_inc                                      0.0000
# url                                           100.0000
# dti                                             0.0605
# delinq_2yrs                                     0.0020
# inq_last_6mths                                  0.0020
# mths_since_last_delinq                         51.2835
# mths_since_last_record                         84.1155
# open_acc                                        0.0020
# pub_rec                                         0.0020
# revol_bal                                       0.0000
# revol_util                                      0.0790
# total_acc                                       0.0020
# out_prncp                                       0.0000
# out_prncp_inv                                   0.0000
# total_pymnt                                     0.0000
# total_pymnt_inv                                 0.0000
# total_rec_prncp                                 0.0000
# total_rec_int                                   0.0000
# total_rec_late_fee                              0.0000
# recoveries                                      0.0000
# collection_recovery_fee                         0.0000
# last_pymnt_amnt                                 0.0000
# collections_12_mths_ex_med                      0.0070
# mths_since_last_major_derog                    74.2820
# policy_code                                     0.0000
# annual_inc_joint                               94.6525
# dti_joint                                      94.6530
# acc_now_delinq                                  0.0020
# tot_coll_amt                                    3.0105
# tot_cur_bal                                     3.0105
# open_acc_6m                                    38.2265
# open_act_il                                    38.2265
# open_il_12m                                    38.2265
# open_il_24m                                    38.2265
# mths_since_rcnt_il                             40.1910
# total_bal_il                                   38.2265
# il_util                                        47.2230
# open_rv_12m                                    38.2265
# open_rv_24m                                    38.2265
# max_bal_bc                                     38.2265
# all_util                                       38.2375
# total_rev_hi_lim                                3.0105
# inq_fi                                         38.2265
# total_cu_tl                                    38.2265
# inq_last_12m                                   38.2265
# acc_open_past_24mths                            2.1555
# avg_cur_bal                                     3.0140
# bc_open_to_buy                                  3.2640
# bc_util                                         3.3155
# chargeoff_within_12_mths                        0.0070
# delinq_amnt                                     0.0020
# mo_sin_old_il_acct                              6.0705
# mo_sin_old_rev_tl_op                            3.0105
# mo_sin_rcnt_rev_tl_op                           3.0105
# mo_sin_rcnt_tl                                  3.0105
# mort_acc                                        2.1555
# mths_since_recent_bc                            3.1855
# mths_since_recent_bc_dlq                       77.0290
# mths_since_recent_inq                          12.9820
# mths_since_recent_revol_delinq                 67.3220
# num_accts_ever_120_pd                           3.0105
# num_actv_bc_tl                                  3.0105
# num_actv_rev_tl                                 3.0105
# num_bc_sats                                     2.5130
# num_bc_tl                                       3.0105
# num_il_tl                                       3.0105
# num_op_rev_tl                                   3.0105
# num_rev_accts                                   3.0105
# num_rev_tl_bal_gt_0                             3.0105
# num_sats                                        2.5130
# num_tl_120dpd_2m                                6.7310
# num_tl_30dpd                                    3.0105
# num_tl_90g_dpd_24m                              3.0105
# num_tl_op_past_12m                              3.0105
# pct_tl_nvr_dlq                                  3.0160
# percent_bc_gt_75                                3.2845
# pub_rec_bankruptcies                            0.0570
# tax_liens                                       0.0060
# tot_hi_cred_lim                                 3.0105
# total_bal_ex_mort                               2.1555
# total_bc_limit                                  2.1555
# total_il_high_credit_limit                      3.0105
# revol_bal_joint                                95.2175
# sec_app_inq_last_6mths                         95.2170
# sec_app_mort_acc                               95.2170
# sec_app_open_acc                               95.2170
# sec_app_revol_util                             95.2950
# sec_app_open_act_il                            95.2170
# sec_app_num_rev_accts                          95.2170
# sec_app_chargeoff_within_12_mths               95.2170
# sec_app_collections_12_mths_ex_med             95.2170
# sec_app_mths_since_last_major_derog            98.4025
# deferral_term                                  99.5300
# hardship_amount                                99.5300
# hardship_length                                99.5300
# hardship_dpd                                   99.5300
# orig_projected_additional_accrued_interest     99.6265
# hardship_payoff_balance_amount                 99.5300
# hardship_last_payment_amount                   99.5300
# settlement_amount                              98.5120
# settlement_percentage                          98.5120
# settlement_term                                98.5120
# loan_status                                     0.0000
# emp_length_int                                  6.4825
# term_int                                        0.0000
# mths_since_loan_issue                           0.0000
# mths_since_earliest_cr                          0.0020
# dtype: float64

# %% [markdown]
# There are a lot of missing values in the data. Because we have a lot of data, it is okay to drop variables that have 60% or more missing values. I proceed to make a list of such variables and drop them from the analysis.

# %%
# Make a list of variables with 60% or more missing values

drop_missing_values = []
for column_name in cont_sample.columns:
    numerator = cont_sample[column_name].isnull().sum()
    denominator = numerator + cont_sample[column_name].count()
    if (numerator*100/denominator) >= 60:
        drop_missing_values.append(column_name)

# %%
# Drop columns with 60% or more of missing values

cont_sample.drop(drop_missing_values, axis = 1, inplace = True)

# %%
# Quick view dataframe

cont_sample.head()
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# 2181401      12500        12500          12500.0      9.44       400.07
# 317128       19000        19000          19000.0      7.46       590.67
# 1310174      16000        16000          16000.0      7.49       497.63
# 605130       10200        10200          10200.0      7.39       316.77
# 421895       24000        24000          24000.0     11.98       533.63
#
#          annual_inc    dti  delinq_2yrs  inq_last_6mths  \
# 2181401     61000.0  24.89          0.0             0.0
# 317128      95000.0  34.77          0.0             0.0
# 1310174    120000.0   8.11          0.0             0.0
# 605130      93000.0  12.27          0.0             0.0
# 421895      72000.0  12.92          0.0             0.0
#
#          mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# 2181401                     NaN       7.0      0.0       8216        46.9
# 317128                      NaN      23.0      0.0      63285        60.0
# 1310174                     NaN      12.0      1.0      14175        65.9
# 605130                     75.0       6.0      0.0       3098        15.6
# 421895                      NaN       7.0      0.0       7002        46.7
#
#          total_acc  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# 2181401       20.0       0.00           0.00  13328.079552         13328.08
# 317128        49.0   14639.71       14639.71   5300.280000          5300.28
# 1310174       27.0       0.00           0.00  16356.300000         16356.30
# 605130        20.0       0.00           0.00   5016.970000          5016.97
# 421895        11.0   20600.47       20600.47   5853.960000          5853.96
#
#          total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 2181401         12500.00         828.08                 0.0        0.00
# 317128           4360.29         939.99                 0.0        0.00
# 1310174         16000.00         356.30                 0.0        0.00
# 605130           3426.20         683.43                 0.0      907.34
# 421895           3399.53        2454.43                 0.0        0.00
#
#          collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
#
#
#          percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 2181401              50.0                   0.0        0.0          71229.0
# 317128               62.5                   0.0        0.0         169728.0
# 1310174              60.0                   1.0        0.0         260340.0
# 605130                0.0                   0.0        0.0         180008.0
# 421895                0.0                   0.0        0.0          53811.0
#
#          total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 2181401            54555.0          9500.0                     53729.0
# 317128            107624.0         93700.0                     68828.0
# 1310174            27063.0         15200.0                     15462.0
# 605130             28441.0         19800.0                     32433.0
# 421895             39143.0          6300.0                     38811.0
#
#          loan_status  emp_length_int  term_int  mths_since_loan_issue  \
# 2181401   Fully Paid             5.0        36                   29.0
# 317128       Current             5.0        36                   24.0
# 1310174   Fully Paid            10.0        36                   63.0
# 605130   Charged Off            10.0        36                   47.0
# 421895       Current             3.0        60                   26.0
#
#          mths_since_earliest_cr
# 2181401                   170.0
# 317128                    304.0
# 1310174                   277.0
# 605130                    163.0
# 421895                    200.0

# %% [markdown]
# For the remaining variables, I proceed to fill missing values with the mean value of that column. Doing so will make sure that any effects are smoothened and distribueted evenly across.

# %%
# Fill missing values in each column with the mean of that column

for column_name in cont_sample.columns:
  if cont_sample[column_name].dtype != 'object':
    cont_sample[column_name].fillna(cont_sample[column_name].mean(), inplace = True)

# %% [markdown]
# I now turn to analyzing the target variable in this case loan status. It is the only categorical variable in the data at this point. I begin analysis by looking a some summary stats.
#
# The loan status variable has 9 distinct loan statuses. Some of these statuses depict loan default and others do not. I binary encode this column and rename it as 'good_bad'. If a loan status has any of the following statuses: 'Charged Off, Default, Late (16-30 days), Does not meet the credit policy. Status: Charged Off' is encoded as 0 which depicts a bad loan or simply that the customer defaulted. All others statuses are encoded as 1 meaning a good loan or customer has not defaulted.

# %%
# Binary encode the loan status target variable 

cont_sample['good_bad'] = np.where(cont_sample['loan_status'].isin(['Charged Off', 'Default', 
                                                                   'Late (16-30 days)',
                                                                   'Does not meet the credit policy. Status:Charged Off',
                                                                   ]), 0, 1)

# %%
# Get a summary count of good and bad loans in each column 

cont_sample.groupby('good_bad').count()
# Out:
#           loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# good_bad
# 0             23719        23719            23719     23719        23719
# 1            176281       176281           176281    176281       176281
#
#           annual_inc     dti  delinq_2yrs  inq_last_6mths  \
# good_bad
# 0              23719   23719        23719           23719
# 1             176281  176281       176281          176281
#
#           mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# good_bad
# 0                          23719     23719    23719      23719       23719
# 1                         176281    176281   176281     176281      176281
#
#           total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# good_bad
# 0             23719      23719          23719        23719            23719
# 1            176281     176281         176281       176281           176281
#
#           total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# good_bad
# 0                   23719          23719               23719       23719
# 1                  176281         176281              176281      176281
#
#           collection_recovery_fee  last_pymnt_amnt  \
# good_bad
# 0                           23719            23719
# 1                          176281           176281
#
#           collections_12_mths_ex_med  policy_code  acc_now_delinq  \
# good_bad
# 0                              23719        23719           23719
# 1                             176281       176281          176281
#
#           tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# good_bad
# 0                23719        23719        23719        23719        23719
# 1               176281       176281       176281       176281       176281
#
#           open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# good_bad
# 0               23719               23719         23719    23719        23719
# 1              176281              176281        176281   176281       176281
#
#           open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# good_bad
# 0               23719       23719     23719             23719   23719
# 1              176281      176281    176281            176281  176281
#
#           total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# good_bad
# 0               23719         23719                 23719        23719
# 1              176281        176281                176281       176281
#
#           bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# good_bad
# 0                  23719    23719                     23719        23719
# 1                 176281   176281                    176281       176281
#
#           mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# good_bad
# 0                      23719                 23719                  23719
# 1                     176281                176281                 176281
#
#           mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# good_bad
# 0                  23719     23719                 23719
# 1                 176281    176281                176281
#
#           mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# good_bad
# 0                         23719                  23719           23719
# 1                        176281                 176281          176281
#
#           num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# good_bad
# 0                   23719        23719      23719      23719          23719
# 1                  176281       176281     176281     176281         176281
#
#           num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# good_bad
# 0                 23719                23719     23719             23719
# 1                176281               176281    176281            176281
#
#           num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# good_bad
# 0                23719               23719               23719
# 1               176281              176281              176281
#
#           pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# good_bad
# 0                  23719             23719                 23719      23719
# 1                 176281            176281                176281     176281
#
#           tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# good_bad
# 0                   23719              23719           23719
# 1                  176281             176281          176281
#
#           total_il_high_credit_limit  loan_status  emp_length_int  term_int  \
# good_bad
# 0                              23719        23719           23719     23719
# 1                             176281       176281          176281    176281
#
#           mths_since_loan_issue  mths_since_earliest_cr
# good_bad
# 0                         23719                   23719
# 1                        176281                  176281

# %% [markdown]
# From the summary, it can be seen that there are more good loans than there are bad loans. This is a welcome news for lenders as more of their loans are getting paid back than customers defaulting on their loans. However, a good number of customers still default on their loans. About 13% of loans are in default. This is certainly a number that lending club or any lending institution would love to see go down some more.

# %%
# loan status is binary encoded, it can now be droped from the analysis at this stage

cont_sample.drop('loan_status', axis = 1, inplace = True)

# %% [markdown]
# There is so much variation in the data because each variable is on a different scale. This may cause some issues for the normality of distributions. It may also overemphasize the impact of outliers, I scale the data to normalize and standardize it.

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
from pandas import DataFrame

scaler = StandardScaler()
scaled_data = scaler.fit_transform(cont_sample)
cont_sample_scaled = pd.DataFrame(scaled_data, columns = cont_sample.columns)

# %%
# Quick view scaled data

cont_sample_scaled.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  annual_inc  \
# 0  -0.275501    -0.275002        -0.272950 -0.753933    -0.169730   -0.112557
# 1   0.430918     0.431597         0.433360 -1.162576     0.543166    0.108962
# 2   0.104878     0.105474         0.107371 -1.156384     0.195171    0.271843
# 3  -0.525465    -0.525030        -0.522875 -1.177023    -0.481295    0.095931
# 4   0.974317     0.975135         0.976676 -0.229714     0.329821   -0.040889
#
#         dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  open_acc  \
# 0  0.452850    -0.354608       -0.647547                0.000000 -0.815675
# 1  1.184307    -0.354608       -0.647547                0.000000  2.021875
# 2 -0.789441    -0.354608       -0.647547                0.000000  0.071059
# 3 -0.481460    -0.354608       -0.647547                2.642155 -0.993022
# 4 -0.433337    -0.354608       -0.647547                0.000000 -0.815675
#
#     pub_rec  revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  \
# 0 -0.349276  -0.371348   -0.138904  -0.347731  -0.588249      -0.588190
# 1 -0.349276   2.047801    0.390809   2.067088   1.346325       1.346608
# 2  1.414130  -0.109572    0.629383   0.235156  -0.588249      -0.588190
# 3 -0.349276  -0.596178   -1.404556  -0.347731  -0.588249      -0.588190
# 4 -0.349276  -0.424678   -0.146991  -1.097158   2.134013       2.134388
#
#    total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 
#
#    mths_since_recent_bc  mths_since_recent_inq  num_accts_ever_120_pd  \
# 0              0.317378               0.171989              -0.377617
# 1             -0.497529               1.784370              -0.377617
# 2              0.003952              -0.007165              -0.377617
# 3              0.129323               0.709449              -0.377617
# 4              0.442749              -0.186318              -0.377617
#
#    num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 0       -0.732683        -1.089031    -0.926062  -1.020911   0.761983
# 1        1.891165         0.714811     1.079778   0.492709   3.499749
# 2        0.579241         0.414171     0.411165   1.790097  -0.743788
# 3       -0.732683        -1.089031    -0.591755  -0.804680   0.077541
# 4       -1.169991        -0.788390    -1.260369  -1.453374  -0.470012
#
#    num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 0      -0.919355      -1.137479            -1.102347 -0.827926
# 1       0.601643       0.127234             0.750374  2.043717
# 2       0.384358       1.139005             0.441588  0.069463
# 3      -1.136640      -0.884536            -1.102347 -1.007403
# 4      -0.919355      -1.011008            -0.793560 -0.827926
#
#    num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# 0         -0.025772      -0.05209           -0.169742            0.515969
# 1         -0.025772      -0.05209           -0.169742           -0.598512
# 2         -0.025772      -0.05209           -0.169742           -0.598512
# 3         -0.025772      -0.05209           -0.169742            1.073209
# 4         -0.025772      -0.05209           -0.169742           -0.598512
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0        0.660280          0.213412             -0.350283  -0.126898
# 1        0.660280          0.564188             -0.350283  -0.126898
# 2        0.660280          0.494033              2.403678  -0.126898
# 3        0.099011         -1.189689             -0.350283  -0.126898
# 4        0.660280         -1.189689             -0.350283  -0.126898
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0        -0.598969           0.070209       -0.603847
# 1        -0.048899           1.132068        3.106599
# 2         0.457126          -0.479879       -0.352665
# 3         0.008510          -0.452306       -0.149956
# 4        -0.696240          -0.238170       -0.744861
#
#    total_il_high_credit_limit  emp_length_int  term_int  \
# 0                    0.222224       -0.258713 -0.635836
# 1                    0.557096       -0.258713 -0.635836
# 2                   -0.626479        1.129438 -0.635836
# 3                   -0.250089        1.129438 -0.635836
# 4                   -0.108634       -0.813974  1.572733
#
#    mths_since_loan_issue  mths_since_earliest_cr  good_bad
# 0              -0.878214               -0.654022  0.366814
# 1              -1.110473                0.766171  0.366814
# 2               0.701146                0.480013  0.366814
# 3              -0.042082               -0.728211 -2.726180
# 4              -1.017569               -0.336068  0.366814

# %%
# Check to see if normalization had any effect

from scipy.stats import jarque_bera
from scipy.stats import normaltest

for column_name in cont_sample_scaled.columns:
    if cont_sample_scaled[column_name].dtype != 'object':
        jb_stats = jarque_bera(cont_sample_scaled[column_name])
        norm_stats = normaltest(cont_sample_scaled[column_name])
        print('\n' + column_name)
        print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
        print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
# Out:
# loan_amnt
# Jarque-Bera test statistics is 20501.357497681787 and p value is 0.0
# Normality test statistics is 16229.41911369734 and p value is 0.0
#
# funded_amnt
# Jarque-Bera test statistics is 20552.19374148605 and p value is 0.0
# Normality test statistics is 16259.156084231747 and p value is 0.0
#
# funded_amnt_inv
# Jarque-Bera test statistics is 20533.865268306206 and p value is 0.0
# Normality test statistics is 16246.842672906225 and p value is 0.0
#
# int_rate
# Jarque-Bera test statistics is 22841.96522978704 and p value is 0.0
# Normality test statistics is 17566.977500731846 and p value is 0.0
#
# installment
# Jarque-Bera test statistics is 37857.325182123124 and p value is 0.0
# Normality test statistics is 26183.15296073437 and p value is 0.0
#
# annual_inc
# Jarque-Bera test statistics is 128565666017637.95 and p value is 0.0
# Normality test statistics is 1110738.7623134048 and p value is 0.0
#
# dti
# Jarque-Bera test statistics is 21386108829.64644 and p value is 0.0
# Normality test statistics is 496299.7899737615 and p value is 0.0
#
# delinq_2yrs
# Jarque-Bera test statistics is 30509060.674031824 and p value is 0.0
# Normality test statistics is 224072.9232025097 and p value is 0.0
#
# inq_last_6mths
# Jarque-Bera test statistics is 2150139.4763011965 and p value is 0.0
# Normality test statistics is 110598.6513976309 and p value is 0.0
#
# mths_since_last_delinq
# Jarque-Bera test statistics is 36069.77049725471 and p value is 0.0
# Normality test statistics is 18929.248103053353 and p value is 0.0
#
# open_acc
# Jarque-Bera test statistics is 160947.14725288757 and p value is 0.0
# Normality test statistics is 51685.64818689856 and p value is 0.0
#
# pub_rec
# Jarque-Bera test statistics is 744162487.7381035 and p value is 0.0
# Normality test statistics is 300049.7078134618 and p value is 0.0
#
# revol_bal
# Jarque-Bera test statistics is 720688499.5422194 and p value is 0.0
# Normality test statistics is 325636.6590824694 and p value is 0.0
#
# revol_util
# Jarque-Bera test statistics is 5783.912264616417 and p value is 0.0
# Normality test statistics is 19910.457321739606 and p value is 0.0
#
# total_acc
# Jarque-Bera test statistics is 69507.49264057651 and p value is 0.0
# Normality test statistics is 34016.93197183785 and p value is 0.0
#
# out_prncp
# Jarque-Bera test statistics is 255454.65815830595 and p value is 0.0
# Normality test statistics is 76980.15257329098 and p value is 0.0
#
# out_prncp_inv
# Jarque-Bera test statistics is 255645.45235056794 and p value is 0.0
# Normality test statistics is 77002.7513338532 and p value is 0.0
#
# total_pymnt
# Jarque-Bera test statistics is 70405.03582310934 and p value is 0.0
# Normality test statistics is 39627.56902733871 and p value is 0.0
#
# total_pymnt_inv
# Jarque-Bera test statistics is 70588.38040227377 and p value is 0.0
# Normality test statistics is 39690.23223925094 and p value is 0.0
#
# total_rec_prncp
# Jarque-Bera test statistics is 65883.4384003045 and p value is 0.0
# Normality test statistics is 38426.1471653351 and p value is 0.0
#
# total_rec_int
# Jarque-Bera test statistics is 919607.7814574195 and p value is 0.0
# Normality test statistics is 109775.56526862993 and p value is 0.0
#
# total_rec_late_fee
# Jarque-Bera test statistics is 5812332669.895629 and p value is 0.0
# Normality test statistics is 453699.7339025663 and p value is 0.0
#
# recoveries
# Jarque-Bera test statistics is 521917549.2358607 and p value is 0.0
# Normality test statistics is 338795.74166434514 and p value is 0.0
#
# collection_recovery_fee
# Jarque-Bera test statistics is 454355977.34034365 and p value is 0.0
# Normality test statistics is 337932.3116836874 and p value is 0.0
#
# last_pymnt_amnt
# Jarque-Bera test statistics is 673824.3428942452 and p value is 0.0
# Normality test statistics is 107103.65683161796 and p value is 0.0
#
# collections_12_mths_ex_med
# Jarque-Bera test statistics is 232296926.90353748 and p value is 0.0
# Normality test statistics is 320537.7881294307 and p value is 0.0
#
# policy_code
# Jarque-Bera test statistics is nan and p value is nan
# Normality test statistics is 496012.30950254423 and p value is 0.0
#
# acc_now_delinq
# Jarque-Bera test statistics is 2473153835.969775 and p value is 0.0
# Normality test statistics is 434690.9017383488 and p value is 0.0
#
# tot_coll_amt
# Jarque-Bera test statistics is 9296561391.744747 and p value is 0.0
# Normality test statistics is 487050.9052797227 and p value is 0.0
#
# tot_cur_bal
# Jarque-Bera test statistics is 28624076.024758376 and p value is 0.0
# Normality test statistics is 172477.515367099 and p value is 0.0
#
# open_acc_6m
# Jarque-Bera test statistics is 933337.7110571495 and p value is 0.0
# Normality test statistics is 98807.81977021116 and p value is 0.0
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1688: RuntimeWarning: invalid value encountered in double_scalars
#   skewness = (1 / n * np.sum(diffx**3)) / (1 / n * np.sum(diffx**2))**(3 / 2.)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1689: RuntimeWarning: invalid value encountered in double_scalars
#   kurtosis = (1 / n * np.sum(diffx**4)) / (1 / n * np.sum(diffx**2))**2
# open_act_il
# Jarque-Bera test statistics is 5202188.442310334 and p value is 0.0
# Normality test statistics is 163200.81026122923 and p value is 0.0
#
# open_il_12m
# Jarque-Bera test statistics is 773381.8492503323 and p value is 0.0
# Normality test statistics is 97153.8892213809 and p value is 0.0
#
# open_il_24m
# Jarque-Bera test statistics is 1051541.9069249115 and p value is 0.0
# Normality test statistics is 99644.74476997521 and p value is 0.0
#
# mths_since_rcnt_il
# Jarque-Bera test statistics is 9041327.608426897 and p value is 0.0
# Normality test statistics is 185610.2151169857 and p value is 0.0
#
# total_bal_il
# Jarque-Bera test statistics is 67444930.89318134 and p value is 0.0
# Normality test statistics is 230720.3965134577 and p value is 0.0
#
# il_util
# Jarque-Bera test statistics is 172212.83972856315 and p value is 0.0
# Normality test statistics is 26218.883604465103 and p value is 0.0
#
# open_rv_12m
# Jarque-Bera test statistics is 2641945.0804055533 and p value is 0.0
# Normality test statistics is 124981.04148580607 and p value is 0.0
#
# open_rv_24m
# Jarque-Bera test statistics is 2066200.1493863116 and p value is 0.0
# Normality test statistics is 117271.39829738744 and p value is 0.0
#
# max_bal_bc
# Jarque-Bera test statistics is 1599902557.3189726 and p value is 0.0
# Normality test statistics is 304935.2027771194 and p value is 0.0
#
# all_util
# Jarque-Bera test statistics is 24963.991983173903 and p value is 0.0
# Normality test statistics is 8458.893709032776 and p value is 0.0
#
# total_rev_hi_lim
# Jarque-Bera test statistics is 214233274.69178665 and p value is 0.0
# Normality test statistics is 258622.1999725224 and p value is 0.0
#
# inq_fi
# Jarque-Bera test statistics is 4245784.689931315 and p value is 0.0
# Normality test statistics is 149255.6161927916 and p value is 0.0
#
# total_cu_tl
# Jarque-Bera test statistics is 18172765.630382795 and p value is 0.0
# Normality test statistics is 199074.10686888304 and p value is 0.0
#
# inq_last_12m
# Jarque-Bera test statistics is 3102395.548992602 and p value is 0.0
# Normality test statistics is 135813.690478137 and p value is 0.0
#
# acc_open_past_24mths
# Jarque-Bera test statistics is 206576.63256802634 and p value is 0.0
# Normality test statistics is 56228.328572797625 and p value is 0.0
#
# avg_cur_bal
# Jarque-Bera test statistics is 22645373.783119652 and p value is 0.0
# Normality test statistics is 187607.5202204864 and p value is 0.0
#
# bc_open_to_buy
# Jarque-Bera test statistics is 6859745.5159010375 and p value is 0.0
# Normality test statistics is 167222.3823337236 and p value is 0.0
#
# bc_util
# Jarque-Bera test statistics is 10062.003444458442 and p value is 0.0
# Normality test statistics is 38091.394878726416 and p value is 0.0
#
# chargeoff_within_12_mths
# Jarque-Bera test statistics is 1896699373.6545324 and p value is 0.0
# Normality test statistics is 414442.84302579693 and p value is 0.0
#
# delinq_amnt
# Jarque-Bera test statistics is 359636890274.4831 and p value is 0.0
# Normality test statistics is 727050.6562203382 and p value is 0.0
#
# mo_sin_old_il_acct
# Jarque-Bera test statistics is 48812.66693913706 and p value is 0.0
# Normality test statistics is 15322.424701720902 and p value is 0.0
#
# mo_sin_old_rev_tl_op
# Jarque-Bera test statistics is 53017.55757524947 and p value is 0.0
# Normality test statistics is 30871.818073827675 and p value is 0.0
#
# mo_sin_rcnt_rev_tl_op
# Jarque-Bera test statistics is 3581366.9431889337 and p value is 0.0
# Normality test statistics is 151965.1340691802 and p value is 0.0
#
# mo_sin_rcnt_tl
# Jarque-Bera test statistics is 17189030.992121752 and p value is 0.0
# Normality test statistics is 195753.72054844527 and p value is 0.0
#
# mort_acc
# Jarque-Bera test statistics is 338212.86375993356 and p value is 0.0
# Normality test statistics is 71281.84855429728 and p value is 0.0
#
# mths_since_recent_bc
# Jarque-Bera test statistics is 4204402.561453265 and p value is 0.0
# Normality test statistics is 155413.51777295544 and p value is 0.0
#
# mths_since_recent_inq
# Jarque-Bera test statistics is 31653.09139380892 and p value is 0.0
# Normality test statistics is 22953.56243514209 and p value is 0.0
#
# num_accts_ever_120_pd
# Jarque-Bera test statistics is 17158403.3707984 and p value is 0.0
# Normality test statistics is 209169.05350519478 and p value is 0.0
#
# num_actv_bc_tl
# Jarque-Bera test statistics is 280524.16248371126 and p value is 0.0
# Normality test statistics is 63229.44234698813 and p value is 0.0
#
# num_actv_rev_tl
# Jarque-Bera test statistics is 333426.95201149484 and p value is 0.0
# Normality test statistics is 68901.35273958517 and p value is 0.0
#
# num_bc_sats
# Jarque-Bera test statistics is 437226.8390978111 and p value is 0.0
# Normality test statistics is 75927.96983372928 and p value is 0.0
#
# num_bc_tl
# Jarque-Bera test statistics is 217818.46489257115 and p value is 0.0
# Normality test statistics is 58915.43787214763 and p value is 0.0
#
# num_il_tl
# Jarque-Bera test statistics is 865435.5852759731 and p value is 0.0
# Normality test statistics is 98641.13873722413 and p value is 0.0
#
# num_op_rev_tl
# Jarque-Bera test statistics is 309439.72386393853 and p value is 0.0
# Normality test statistics is 66684.09892686838 and p value is 0.0
#
# num_rev_accts
# Jarque-Bera test statistics is 169473.58240338514 and p value is 0.0
# Normality test statistics is 53993.29555122426 and p value is 0.0
#
# num_rev_tl_bal_gt_0
# Jarque-Bera test statistics is 256311.3285288827 and p value is 0.0
# Normality test statistics is 62603.992085373466 and p value is 0.0
#
# num_sats
# Jarque-Bera test statistics is 171872.84410034923 and p value is 0.0
# Normality test statistics is 52941.74933126273 and p value is 0.0
#
# num_tl_120dpd_2m
# Jarque-Bera test statistics is 52197744236.77519 and p value is 0.0
# Normality test statistics is 606926.6394178374 and p value is 0.0
#
# num_tl_30dpd
# Jarque-Bera test statistics is 3385861519.683438 and p value is 0.0
# Normality test statistics is 460354.04175602493 and p value is 0.0
#
# num_tl_90g_dpd_24m
# Jarque-Bera test statistics is 1123733566.1809387 and p value is 0.0
# Normality test statistics is 377802.34657327866 and p value is 0.0
#
# num_tl_op_past_12m
# Jarque-Bera test statistics is 298141.55554640706 and p value is 0.0
# Normality test statistics is 64934.23968716779 and p value is 0.0
#
# pct_tl_nvr_dlq
# Jarque-Bera test statistics is 606530.5299455976 and p value is 0.0
# Normality test statistics is 97688.82698277118 and p value is 0.0
#
# percent_bc_gt_75
# Jarque-Bera test statistics is 15283.224937405368 and p value is 0.0
# Normality test statistics is 176682.00165740048 and p value is 0.0
#
# pub_rec_bankruptcies
# Jarque-Bera test statistics is 3524140.928772775 and p value is 0.0
# Normality test statistics is 149439.5899480371 and p value is 0.0
#
# tax_liens
# Jarque-Bera test statistics is 19329815287.96534 and p value is 0.0
# Normality test statistics is 474805.9844479727 and p value is 0.0
#
# tot_hi_cred_lim
# Jarque-Bera test statistics is 24189368.89646838 and p value is 0.0
# Normality test statistics is 167240.02551864285 and p value is 0.0
#
# total_bal_ex_mort
# Jarque-Bera test statistics is 21481678.85363135 and p value is 0.0
# Normality test statistics is 188996.92174148973 and p value is 0.0
#
# total_bc_limit
# Jarque-Bera test statistics is 2107462.391364151 and p value is 0.0
# Normality test statistics is 125881.01408217172 and p value is 0.0
#
# total_il_high_credit_limit
# Jarque-Bera test statistics is 19486981.469979677 and p value is 0.0
# Normality test statistics is 175459.09995192738 and p value is 0.0
#
# emp_length_int
# Jarque-Bera test statistics is 18153.345924814315 and p value is 0.0
# Normality test statistics is 1668584.7295446654 and p value is 0.0
#
# term_int
# Jarque-Bera test statistics is 39754.0875703618 and p value is 0.0
# Normality test statistics is 117348.57057075885 and p value is 0.0
#
# mths_since_loan_issue
# Jarque-Bera test statistics is 23466.14900771788 and p value is 0.0
# Normality test statistics is 17870.693859619743 and p value is 0.0
#
# mths_since_earliest_cr
# Jarque-Bera test statistics is 47888.19176369499 and p value is 0.0
# Normality test statistics is 28622.161782530402 and p value is 0.0
#
# good_bad
# Jarque-Bera test statistics is 291559.64165056235 and p value is 0.0
# Normality test statistics is 87177.2389278401 and p value is 0.0

# %% [markdown]
# All variables follow the normal distribution, as such, I proceed with the analysis.

# %%
cont_sample_scaled.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  annual_inc  \
# 
# 4              -1.017569               -0.336068  0.366814

# %% [markdown]
# I now check the relationship between the target variable (good_bad) and the continous variables. I drop variables that are highly inter-correlated within the feature set. In other words, I drop variables based on multicollinearity. The remaining set of variables will be used in building the credit risk model and their effects analyzed in conjuction with the categorical variables that have been excluded thus far.
#
# Because there are categorical variables that are yet to be analyzed alongside their continous counterparts, it is not safe to drop variables just yet based on their weak correlation with the target. Variables showing weak correlation now may be significant in predicting loan default, as such, I carry them on and analyze their full effect in the eventual model, however, I drop multicollinear variables.

# %%
# Get a correlation matrix

matrix = cont_sample_scaled.corr()

# %%
matrix
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                    1.000000     0.999753         0.999031  0.100890
# funded_amnt                  0.999753     1.000000         0.999341  0.100832
# funded_amnt_inv              0.999031     0.999341         1.000000  0.100844
# int_rate                     0.100890     0.100832         0.100844  1.000000
# installment                  0.945620     0.945965         0.945110  0.126927
# annual_inc                   0.144004     0.143949         0.143834 -0.035842
# dti                          0.042696     0.042917         0.043390  0.127587
# delinq_2yrs                 -0.007750    -0.007670        -0.007560  0.060773
# inq_last_6mths              -0.026790    -0.027089        -0.029035  0.186047
# mths_since_last_delinq      -0.010851    -0.010804        -0.010121 -0.028588
# open_acc                     0.183195     0.183306         0.183519 -0.010841
# pub_rec                     -0.057652    -0.057533        -0.057201  0.053629
# revol_bal                    0.320969     0.320804         0.320002 -0.027224
# revol_util                   0.096808     0.096800         0.096575  0.263729
# total_acc                    0.199580     0.199439         0.199349 -0.039996
# out_prncp                    0.473329     0.473785         0.474485  0.021161
# out_prncp_inv                0.473344     0.473800         0.474503  0.021186
# total_pymnt                  0.651002     0.650861         0.649917  0.099524
# total_pymnt_inv              0.651032     0.650952         0.651171  0.099615
# total_rec_prncp              0.577787     0.577687         0.576769 -0.026609
# total_rec_int                0.583461     0.583250         0.582722  0.413859
# total_rec_late_fee           0.071910     0.071916         0.071480  0.068754
# recoveries                   0.117442     0.117442         0.117029  0.143065
# collection_recovery_fee      0.113817     0.113850         0.113486  0.133926
# last_pymnt_amnt              0.318294     0.318290         0.318030  0.077996
# collections_12_mths_ex_med  -0.021020    -0.020958        -0.020780  0.020220
# policy_code                       NaN          NaN              NaN       NaN
# acc_now_delinq               0.000350     0.000385         0.000428  0.013430
# tot_coll_amt                -0.024860    -0.024866        -0.024861  0.014730
# tot_cur_bal                  0.309704     0.309783         0.309609 -0.084308
# open_acc_6m                 -0.019360    -0.019365        -0.019388  0.112411
# open_act_il                  0.028202     0.028209         0.028192  0.032505
# open_il_12m                  0.000865     0.000865         0.000845  0.127316
# open_il_24m                  0.021660     0.021665         0.021635  0.124658
# mths_since_rcnt_il          -0.013223    -0.013227        -0.013197 -0.065978
# total_bal_il                 0.123605     0.123637         0.123559  0.031331
# il_util                     -0.065268    -0.065285        -0.065245  0.108946
# open_rv_12m                 -0.038413    -0.038423        -0.038437  0.096917
# open_rv_24m                 -0.030283    -0.030291        -0.030322  0.102920
# max_bal_bc                   0.305956     0.306034         0.305866 -0.048389
# all_util                     0.000705     0.000705         0.000690  0.240465
# total_rev_hi_lim             0.340273     0.340360         0.340155 -0.187553
# inq_fi                      -0.001880    -0.001880        -0.001884  0.112365
# total_cu_tl                  0.060980     0.060995         0.060958  0.009182
# inq_last_12m                 0.006946     0.006948         0.006914  0.136735
# acc_open_past_24mths         0.001848     0.001826         0.001788  0.169924
# avg_cur_bal                  0.225549     0.225606         0.225491 -0.082008
# bc_open_to_buy               0.204243     0.204303         0.204226 -0.292129
# bc_util                      0.044798     0.044796         0.044710  0.272339
# chargeoff_within_12_mths    -0.003241    -0.003197        -0.003097  0.013448
# delinq_amnt                  0.000706     0.000717         0.000724  0.006825
# mo_sin_old_il_acct           0.119480     0.119511         0.119446 -0.060587
# mo_sin_old_rev_tl_op         0.162042     0.162083         0.161994 -0.134675
# mo_sin_rcnt_rev_tl_op        0.051299     0.051312         0.051302 -0.090826
# mo_sin_rcnt_tl               0.028367     0.028374         0.028367 -0.109479
# mort_acc                     0.220307     0.220362         0.220224 -0.091821
# mths_since_recent_bc         0.031514     0.031527         0.031525 -0.073995
# mths_since_recent_inq        0.003929     0.003934         0.003932 -0.134666
# num_accts_ever_120_pd       -0.052382    -0.052396        -0.052372  0.048972
# num_actv_bc_tl               0.188658     0.188706         0.188558  0.021453
# num_actv_rev_tl              0.147336     0.147374         0.147233  0.081194
# num_bc_sats                  0.210941     0.210994         0.210840 -0.060920
# num_bc_tl                    0.188769     0.188818         0.188657 -0.081552
# num_il_tl                    0.081257     0.081278         0.081224  0.020363
# num_op_rev_tl                0.162032     0.162074         0.161939 -0.018785
# num_rev_accts                0.160406     0.160447         0.160304 -0.057751
# num_rev_tl_bal_gt_0          0.146817     0.146855         0.146714  0.082037
# num_sats                     0.179398     0.179442         0.179302 -0.013454
# num_tl_120dpd_2m            -0.000407    -0.000407        -0.000437  0.007290
# num_tl_30dpd                 0.001113     0.001113         0.001081  0.008888
# num_tl_90g_dpd_24m          -0.023891    -0.023897        -0.023888  0.032098
# num_tl_op_past_12m          -0.024207    -0.024213        -0.024233  0.177276
# pct_tl_nvr_dlq               0.088418     0.088440         0.088397 -0.076171
# percent_bc_gt_75             0.019924     0.019917         0.019864  0.268234
# pub_rec_bankruptcies        -0.084714    -0.084620        -0.084419  0.055246
# tax_liens                    0.010302     0.010376         0.010520  0.016236
# tot_hi_cred_lim              0.336963     0.337049         0.336862 -0.123185
# total_bal_ex_mort            0.272625     0.272695         0.272514  0.009581
# total_bc_limit               0.371006     0.371108         0.370901 -0.237178
# total_il_high_credit_limit   0.204707     0.204760         0.204626 -0.000056
# emp_length_int               0.079062     0.079115         0.079559 -0.010826
# term_int                     0.395166     0.394741         0.395111  0.376501
# mths_since_loan_issue       -0.062345    -0.064122        -0.069779  0.041928
# mths_since_earliest_cr       0.140995     0.140677         0.139757 -0.106607
# good_bad                    -0.017731    -0.017543        -0.016802 -0.201226
#
#                             installment  annual_inc       dti  delinq_2yrs  \
# loan_amnt                      0.945620    0.144004  0.042696    -0.007750
# funded_amnt                    0.945965    0.143949  0.042917    -0.007670
# total_pymnt                       0.028734               -0.028242  0.127593
# total_pymnt_inv                   0.027130               -0.027526  0.127947
# total_rec_prncp                   0.012863               -0.022627  0.115159
# total_rec_int                     0.053141               -0.031682  0.105918
# total_rec_late_fee                0.019765               -0.026200  0.000940
# recoveries                        0.049129               -0.009278  0.032194
# collection_recovery_fee           0.044862               -0.009296  0.032940
# last_pymnt_amnt                   0.031257                0.003068  0.066114
# collections_12_mths_ex_med        0.013049               -0.034567  0.006205
# policy_code                            NaN                     NaN       NaN
# acc_now_delinq                   -0.001702               -0.133465  0.017413
# tot_coll_amt                      0.019538                0.022894  0.005472
# tot_cur_bal                       0.031749               -0.048105  0.249950
# open_acc_6m                       0.300124                0.024059  0.225538
# open_act_il                       0.026898               -0.010216  0.427385
# open_il_12m                       0.116267                0.022926  0.150250
# open_il_24m                       0.096879                0.027993  0.209080
# mths_since_rcnt_il               -0.063236               -0.009162 -0.134677
# total_bal_il                      0.042718               -0.005336  0.279424
# il_util                           0.058819                0.024859  0.099686
# open_rv_12m                       0.227628                0.035303  0.280547
# open_rv_24m                       0.199039                0.052566  0.371247
# max_bal_bc                       -0.039052                0.003535  0.099735
# all_util                         -0.023500                0.009754 -0.000993
# total_rev_hi_lim                  0.024083               -0.004144  0.412373
# inq_fi                            0.147369                0.003695  0.096175
# total_cu_tl                       0.027600               -0.005130  0.086888
# inq_last_12m                      0.332036                0.004130  0.150282
# acc_open_past_24mths              0.265434                0.078406  0.489435
# avg_cur_bal                      -0.019612               -0.042612 -0.105804
# bc_open_to_buy                    0.014187                0.001827  0.305340
# bc_util                          -0.066611                0.005895 -0.095032
# chargeoff_within_12_mths          0.013507               -0.095496  0.006457
# delinq_amnt                       0.003624               -0.031115  0.007736
# mo_sin_old_il_acct                0.015121                0.001127  0.145409
# mo_sin_old_rev_tl_op             -0.002945               -0.028398  0.144542
# mo_sin_rcnt_rev_tl_op            -0.179881               -0.044726 -0.234787
# mo_sin_rcnt_tl                   -0.216269               -0.038584 -0.230527
# mort_acc                          0.045198               -0.045550  0.134270
# mths_since_recent_bc             -0.121277               -0.055890 -0.204841
# mths_since_recent_inq            -0.527507               -0.002133 -0.098901
# num_accts_ever_120_pd             0.048579                0.010666  0.023857
# num_actv_bc_tl                    0.073453                0.024829  0.553267
# num_actv_rev_tl                   0.121877                0.011575  0.664564
# num_bc_sats                       0.118351                0.016323  0.634140
# num_bc_tl                         0.134465               -0.000251  0.536116
# num_il_tl                         0.065668               -0.012046  0.393405
# num_op_rev_tl                     0.140916               -0.006819  0.827380
# num_rev_accts                     0.154855               -0.026081  0.661605
# num_rev_tl_bal_gt_0               0.104994                0.011604  0.666218
# num_sats                          0.136577               -0.021827  0.989686
# num_tl_120dpd_2m                  0.005656               -0.052145  0.001674
# num_tl_30dpd                     -0.005848               -0.111333  0.018158
# num_tl_90g_dpd_24m                0.030679               -0.211153  0.013115
# num_tl_op_past_12m                0.311895                0.057749  0.363904
# pct_tl_nvr_dlq                   -0.026066                0.143731  0.108193
# all_util                   -0.001974   0.095171    0.527308   0.008829
# total_rev_hi_lim           -0.102768   0.803363   -0.139843   0.329854
# inq_fi                      0.045709  -0.035380   -0.065469   0.132623
# total_cu_tl                -0.000134   0.036710    0.021253   0.231241
# inq_last_12m                0.070837  -0.019361   -0.099466   0.169813
# acc_open_past_24mths        0.098442  -0.006928   -0.216431   0.429427
# avg_cur_bal                -0.051873   0.281902    0.123225   0.051295
# bc_open_to_buy             -0.084290   0.164846   -0.474433   0.232041
# bc_util                    -0.022441   0.175327    0.848752  -0.067123
# chargeoff_within_12_mths   -0.007071  -0.009110   -0.010693   0.040498
# delinq_amnt                -0.000200   0.006504   -0.004816   0.009539
# mo_sin_old_il_acct          0.033739   0.102082    0.065065   0.330565
# mo_sin_old_rev_tl_op        0.039504   0.230423    0.021479   0.278430
# mo_sin_rcnt_rev_tl_op      -0.063743   0.021864    0.177878  -0.168800
# mo_sin_rcnt_tl             -0.059094   0.023134    0.163866  -0.212681
# mort_acc                   -0.014771   0.218252    0.037617   0.362946
# mths_since_recent_bc       -0.048588   0.028804    0.142259  -0.120265
# mths_since_recent_inq      -0.053587   0.008614    0.087247  -0.119953
# num_accts_ever_120_pd       0.013772  -0.077214   -0.021634   0.144454
# num_actv_bc_tl             -0.032426   0.315834    0.104524   0.307493
# num_actv_rev_tl             0.002270   0.316426    0.108757   0.410741
# num_bc_sats                -0.035461   0.285994   -0.119139   0.406944
# num_bc_tl                  -0.004001   0.238087   -0.122226   0.617881
# num_il_tl                  -0.014963   0.028829    0.022939   0.682884
# num_op_rev_tl               0.005017   0.245914   -0.193158   0.565963
# num_rev_accts               0.022571   0.225682   -0.165135   0.752016
# num_rev_tl_bal_gt_0        -0.002241   0.315333    0.115054   0.410939
# num_sats                   -0.023955   0.238514   -0.132174   0.706374
# num_tl_120dpd_2m            0.001603  -0.005601   -0.007879   0.007713
# num_tl_30dpd               -0.001358   0.000182   -0.018604   0.021990
# num_tl_90g_dpd_24m         -0.003055  -0.030738   -0.006224   0.070641
# num_tl_op_past_12m          0.086372  -0.018513   -0.211779   0.325104
# pct_tl_nvr_dlq             -0.010850   0.113098   -0.029511   0.020911
# percent_bc_gt_75           -0.032482   0.141522    0.722284  -0.053558
# pub_rec_bankruptcies        0.658113  -0.109409   -0.073019   0.026984
# tax_liens                   0.692254  -0.011004   -0.004944  -0.018179
# tot_hi_cred_lim            -0.074925   0.475253    0.027797   0.342089
# total_bal_ex_mort          -0.054586   0.498198    0.121987   0.434573
# total_bc_limit             -0.126459   0.476860   -0.175077   0.288629
# total_il_high_credit_limit -0.025046   0.137848    0.034055   0.417089
# emp_length_int              0.031650   0.086223    0.033246   0.103541
# term_int                   -0.016272   0.081121    0.065168   0.095396
# mths_since_loan_issue      -0.002045   0.003136    0.162754   0.064295
# mths_since_earliest_cr      0.059620   0.215818    0.060696   0.286441
# good_bad                   -0.033516   0.021832   -0.065547  -0.009963
#
#                             out_prncp  out_prncp_inv  total_pymnt  \
# loan_amnt                    0.473329       0.473344     0.651002
# funded_amnt                  0.473785       0.473800     0.650861
# funded_amnt_inv              0.474485       0.474503     0.649917
# int_rate                     0.021161       0.021186     0.099524
# installment                  0.388714       0.388703     0.651342
# annual_inc                   0.062278       0.062281     0.099704
# dti                          0.065806       0.065800    -0.007055
# delinq_2yrs                 -0.027812      -0.027823     0.016368
# inq_last_6mths              -0.088364      -0.088369     0.028734
# mths_since_last_delinq       0.016700       0.016706    -0.028242
# open_acc                     0.071837       0.071829     0.127593
# pub_rec                     -0.052513      -0.052514    -0.022195
# revol_bal                    0.121269       0.121272     0.242935
# revol_util                  -0.044641      -0.044636     0.160599
# total_acc                    0.013045       0.013045     0.190021
# out_prncp                    1.000000       0.999999    -0.230163
# out_prncp_inv                0.999999       1.000000    -0.230157
# total_pymnt                 -0.230163      -0.230157     1.000000
# total_pymnt_inv             -0.229344      -0.229337     0.999397
# total_rec_prncp             -0.294475      -0.294466     0.967114
# total_rec_int                0.094184       0.094175     0.696044
# total_rec_late_fee           0.001148       0.001145     0.066551
# recoveries                  -0.109947      -0.109936     0.004095
# collection_recovery_fee     -0.105337      -0.105326     0.007191
# last_pymnt_amnt             -0.269140      -0.269112     0.585144
# collections_12_mths_ex_med  -0.006036      -0.006040    -0.019225
# policy_code                       NaN            NaN          NaN
# acc_now_delinq              -0.020736      -0.020738     0.017971
# tot_coll_amt                -0.015573      -0.015582    -0.014541
# tot_cur_bal                  0.123785       0.123799     0.228981
# open_acc_6m                 -0.048221      -0.048227     0.004959
# open_act_il                  0.020355       0.020361     0.015250
# open_il_12m                 -0.029446      -0.029448     0.013278
# open_il_24m                 -0.020945      -0.020946     0.028633
# mths_since_rcnt_il           0.006534       0.006540    -0.011606
# total_bal_il                 0.074785       0.074789     0.067621
# il_util                     -0.068167      -0.068166    -0.018225
# open_rv_12m                 -0.057475      -0.057484    -0.004667
# open_rv_24m                 -0.058328      -0.058344     0.002175
# max_bal_bc                   0.187039       0.187051     0.170393
# all_util                    -0.035048      -0.035044     0.038708
# total_rev_hi_lim             0.178055       0.178060     0.205601
# inq_fi                      -0.006719      -0.006727    -0.005589
# total_cu_tl                  0.028639       0.028639     0.035265
# inq_last_12m                -0.036498      -0.036507     0.022731
# acc_open_past_24mths        -0.031121      -0.031133    -0.001923
# avg_cur_bal                  0.087058       0.087072     0.171761
# bc_open_to_buy               0.163485       0.163492     0.065438
# bc_util                     -0.069487      -0.069481     0.126645
# chargeoff_within_12_mths    -0.008566      -0.008571     0.005157
# delinq_amnt                 -0.004844      -0.004844     0.005745
# mo_sin_old_il_acct           0.038131       0.038136     0.103069
# mo_sin_old_rev_tl_op         0.045070       0.045079     0.140830
# mo_sin_rcnt_rev_tl_op        0.057835       0.057841     0.020844
# mo_sin_rcnt_tl               0.043976       0.043980     0.009693
# mort_acc                     0.019506       0.019525     0.224397
# mths_since_recent_bc         0.031083       0.031088     0.023870
# mths_since_recent_inq        0.039919       0.039925    -0.014673
# num_accts_ever_120_pd       -0.030646      -0.030647    -0.028183
# num_actv_bc_tl               0.075962       0.075954     0.135809
# num_actv_rev_tl              0.041807       0.041796     0.122174
# num_bc_sats                  0.091756       0.091748     0.135603
# num_bc_tl                   -0.004470      -0.004471     0.190149
# num_il_tl                    0.024051       0.024053     0.060012
# num_op_rev_tl                0.056385       0.056374     0.115855
# num_rev_accts               -0.010377      -0.010382     0.166871
# num_rev_tl_bal_gt_0          0.040956       0.040946     0.123410
# num_sats                     0.068170       0.068162     0.126457
# num_tl_120dpd_2m            -0.010160      -0.010166     0.008292
# num_tl_30dpd                -0.016539      -0.016538     0.016330
# num_tl_90g_dpd_24m          -0.024208      -0.024212    -0.005465
# num_tl_op_past_12m          -0.041553      -0.041562    -0.016536
# pct_tl_nvr_dlq               0.042348       0.042354     0.049896
# percent_bc_gt_75            -0.076054      -0.076044     0.102314
# pub_rec_bankruptcies        -0.031704      -0.031710    -0.068402
# tax_liens                   -0.023766      -0.023765     0.029026
# tot_hi_cred_lim              0.147581       0.147595     0.236920
# total_bal_ex_mort            0.130178       0.130178     0.181278
# total_bc_limit               0.210509       0.210514     0.210647
# total_il_high_credit_limit   0.119236       0.119236     0.117211
# emp_length_int               0.008561       0.008571     0.083986
# term_int                     0.287367       0.287440     0.209533
# mths_since_loan_issue       -0.538120      -0.538079     0.380767
# mths_since_earliest_cr      -0.066187      -0.066172     0.210842
# good_bad                     0.207555       0.207535     0.133029
#
#                             total_pymnt_inv  total_rec_prncp  total_rec_int  \
# loan_amnt                          0.651032         0.577787       0.583461
# funded_amnt                        0.650952         0.577687       0.583250
# funded_amnt_inv                    0.651171         0.576769       0.582722
# int_rate                           0.099615        -0.026609       0.413859
# installment                        0.651254         0.598204       0.521459
# annual_inc                         0.099705         0.098823       0.060320
# dti                               -0.006605        -0.029588       0.059642
# delinq_2yrs                        0.016425         0.007741       0.032678
# inq_last_6mths                     0.027130         0.012863       0.053141
# mths_since_last_delinq            -0.027526        -0.022627      -0.031682
# open_acc                           0.127947         0.115159       0.105918
# pub_rec                           -0.021918        -0.026591      -0.002426
# revol_bal                          0.242346         0.230459       0.177851
# revol_util                         0.160469         0.115331       0.223885
# total_acc                          0.190069         0.183650       0.121229
# out_prncp                         -0.229344        -0.294475       0.094184
# out_prncp_inv                     -0.229337        -0.294466       0.094175
# total_pymnt                        0.999397         0.967114       0.696044
# total_pymnt_inv                    1.000000         0.966477       0.695826
# total_rec_prncp                    0.966477         1.000000       0.501614
# total_rec_int                      0.695826         0.501614       1.000000
# total_rec_late_fee                 0.066245         0.032079       0.125480
# recoveries                         0.003978        -0.107305       0.076488
# collection_recovery_fee            0.007077        -0.100660       0.075940
# last_pymnt_amnt                    0.585096         0.669632       0.107781
# collections_12_mths_ex_med        -0.019073        -0.020746      -0.007230
# policy_code                             NaN              NaN            NaN
# acc_now_delinq                     0.018011         0.015352       0.015363
# tot_coll_amt                      -0.014545        -0.014569      -0.008752
# tot_cur_bal                        0.229027         0.228458       0.135331
# open_acc_6m                        0.004936        -0.000661       0.012647
# open_act_il                        0.015246         0.009002       0.026946
# open_il_12m                        0.013267         0.007018       0.019990
# open_il_24m                        0.028626         0.020528       0.034002
# mths_since_rcnt_il                -0.011592        -0.007931      -0.014121
# total_bal_il                       0.067624         0.058996       0.063421
# il_util                           -0.018224        -0.023037      -0.000114
# open_rv_12m                       -0.004694        -0.009462       0.005830
# open_rv_24m                        0.002145        -0.004147       0.013190
# max_bal_bc                         0.170428         0.164042       0.119050
# all_util                           0.038700         0.013774       0.094494
# total_rev_hi_lim                   0.205637         0.215092       0.092410
# inq_fi                            -0.005591        -0.011274       0.010528
# total_cu_tl                        0.035270         0.034705       0.020495
# inq_last_12m                       0.022716         0.014793       0.030956
# acc_open_past_24mths              -0.001940        -0.015256       0.022954
# avg_cur_bal                        0.171803         0.176343       0.088717
# bc_open_to_buy                     0.065488         0.097909      -0.054742
# bc_util                            0.126611         0.083334       0.198054
# chargeoff_within_12_mths           0.005254         0.004378       0.004667
# delinq_amnt                        0.005751         0.004987       0.005738
# mo_sin_old_il_acct                 0.103088         0.098235       0.075496
# mo_sin_old_rev_tl_op               0.140859         0.142802       0.077487
# mo_sin_rcnt_rev_tl_op              0.020858         0.025172       0.007116
# mo_sin_rcnt_tl                     0.009695         0.016264      -0.004996
# mort_acc                           0.224427         0.225313       0.127055
# mths_since_recent_bc               0.023882         0.025947       0.014712
# mths_since_recent_inq             -0.014686        -0.004456      -0.031361
# num_accts_ever_120_pd             -0.028196        -0.030931      -0.008800
# num_actv_bc_tl                     0.135811         0.117586       0.130327
# num_actv_rev_tl                    0.122159         0.095084       0.146546
# num_bc_sats                        0.135614         0.131828       0.086897
# num_bc_tl                          0.190148         0.191325       0.100143
# num_il_tl                          0.060016         0.052343       0.053032
# num_op_rev_tl                      0.115853         0.106424       0.090355
# num_rev_accts                      0.166868         0.164871       0.095368
# num_rev_tl_bal_gt_0                0.123395         0.095755       0.149139
# num_sats                           0.126457         0.114383       0.104297
# num_tl_120dpd_2m                   0.008266         0.007306       0.006923
# num_tl_30dpd                       0.016297         0.014487       0.013361
# num_tl_90g_dpd_24m                -0.005470        -0.007543       0.001969
# num_tl_op_past_12m                -0.016560        -0.028103       0.011553
# pct_tl_nvr_dlq                     0.049912         0.055819       0.010699
# percent_bc_gt_75                   0.102289         0.061318       0.176418
# pub_rec_bankruptcies              -0.068263        -0.068877      -0.040323
# tax_liens                          0.029169         0.023569       0.031668
# tot_hi_cred_lim                    0.236970         0.239888       0.130111
# total_bal_ex_mort                  0.181295         0.165341       0.150302
# total_bc_limit                     0.210698         0.225314       0.081295
# total_il_high_credit_limit         0.117220         0.104659       0.103259
# emp_length_int                     0.084454         0.075999       0.071875
# term_int                           0.210062         0.083402       0.489522
# mths_since_loan_issue              0.375500         0.365186       0.250153
# mths_since_earliest_cr             0.210079         0.207176       0.130986
# good_bad                           0.133098         0.216887      -0.042991
#
#                             total_rec_late_fee  recoveries  \
# loan_amnt                             0.071910    0.117442
# funded_amnt                           0.071916    0.117442
# funded_amnt_inv                       0.071480    0.117029
# int_rate                              0.068754    0.143065
# installment                           0.082923    0.115315
# annual_inc                            0.013987    0.006072
# dti                                  -0.000064    0.024017
# delinq_2yrs                           0.033897    0.014100
# inq_last_6mths                        0.019765    0.049129
# mths_since_last_delinq               -0.026200   -0.009278
# open_acc                              0.000940    0.032194
# pub_rec                               0.010460    0.010650
# revol_bal                             0.014885    0.020234
# revol_util                            0.032262    0.047242
# total_acc                             0.005386    0.042601
# out_prncp                             0.001148   -0.109947
# out_prncp_inv                         0.001145   -0.109936
# total_pymnt                           0.066551    0.004095
# total_pymnt_inv                       0.066245    0.003978
# total_rec_prncp                       0.032079   -0.107305
# total_rec_int                         0.125480    0.076488
# total_rec_late_fee                    1.000000    0.063086
# recoveries                            0.063086    1.000000
# collection_recovery_fee               0.063631    0.968209
# last_pymnt_amnt                      -0.027421   -0.086507
# collections_12_mths_ex_med            0.005388    0.001928
# policy_code                                NaN         NaN
# acc_now_delinq                        0.004041    0.012761
# tot_coll_amt                         -0.001105    0.000723
# tot_cur_bal                           0.022865    0.008675
# open_acc_6m                           0.014181    0.028488
# open_act_il                           0.010157    0.005849
# open_il_12m                           0.018542    0.026967
# open_il_24m                           0.021099    0.030161
# mths_since_rcnt_il                   -0.008094   -0.015446
# total_bal_il                          0.015771    0.013428
# il_util                               0.011170    0.015572
# open_rv_12m                           0.003472    0.023238
# open_rv_24m                           0.002415    0.028658
# max_bal_bc                            0.004429    0.007711
# all_util                              0.024849    0.023121
# total_rev_hi_lim                     -0.002792    0.000785
# inq_fi                                0.016549    0.014016
# total_cu_tl                           0.014092    0.007890
# inq_last_12m                          0.024546    0.026503
# acc_open_past_24mths                  0.016510    0.063889
# avg_cur_bal                           0.021642   -0.003608
# bc_open_to_buy                       -0.022598   -0.028156
# bc_util                               0.026508    0.045598
# chargeoff_within_12_mths              0.002272    0.003018
# delinq_amnt                           0.002029    0.000129
# mo_sin_old_il_acct                    0.004676    0.003224
# mo_sin_old_rev_tl_op                 -0.004450    0.000445
# mo_sin_rcnt_rev_tl_op                -0.002566   -0.030068
# mo_sin_rcnt_tl                       -0.010424   -0.035524
# mort_acc                              0.001260    0.012878
# mths_since_recent_bc                 -0.000621   -0.025578
# mths_since_recent_inq                -0.017670   -0.033653
# num_accts_ever_120_pd                 0.010804    0.002102
# num_actv_bc_tl                        0.001399    0.026940
# num_actv_rev_tl                       0.003031    0.039272
# num_bc_sats                          -0.006577    0.020361
# num_bc_tl                            -0.007968    0.033967
# num_il_tl                             0.018194    0.023879
# num_op_rev_tl                        -0.010896    0.029459
# num_rev_accts                        -0.010247    0.037130
# num_rev_tl_bal_gt_0                   0.002463    0.038944
# num_sats                              0.000316    0.031538
# num_tl_120dpd_2m                      0.000585    0.003969
# num_tl_30dpd                          0.005097    0.007622
# num_tl_90g_dpd_24m                    0.005593    0.004572
# num_tl_op_past_12m                    0.015111    0.053655
# pct_tl_nvr_dlq                       -0.033114    0.002247
# percent_bc_gt_75                      0.027618    0.045334
# pub_rec_bankruptcies                 -0.009760    0.004284
# tax_liens                             0.024090    0.009266
# tot_hi_cred_lim                       0.019683    0.005192
# total_bal_ex_mort                     0.028651    0.026215
# total_bc_limit                       -0.013219   -0.006559
# total_il_high_credit_limit            0.026045    0.020289
# emp_length_int                       -0.003499    0.011123
# term_int                              0.022585    0.106404
# mths_since_loan_issue                 0.018743    0.090920
# mths_since_earliest_cr                0.002902    0.021354
# good_bad                             -0.097801   -0.509539
#
#                             collection_recovery_fee  last_pymnt_amnt  \
# loan_amnt                                  0.113817         0.318294
# funded_amnt                                0.113850         0.318290
# funded_amnt_inv                            0.113486         0.318030
# int_rate                                   0.133926         0.077996
# installment                                0.111655         0.307464
# annual_inc                                 0.006299         0.053412
# dti                                        0.025105        -0.018474
# delinq_2yrs                                0.014949        -0.004951
# inq_last_6mths                             0.044862         0.031257
# mths_since_last_delinq                    -0.009296         0.003068
# open_acc                                   0.032940         0.066114
# pub_rec                                    0.011978        -0.007502
# revol_bal                                  0.020832         0.104820
# revol_util                                 0.043983         0.020795
# total_acc                                  0.042484         0.133938
# out_prncp                                 -0.105337        -0.269140
# out_prncp_inv                             -0.105326        -0.269112
# total_pymnt                                0.007191         0.585144
# total_pymnt_inv                            0.007077         0.585096
# total_rec_prncp                           -0.100660         0.669632
# total_rec_int                              0.075940         0.107781
# total_rec_late_fee                         0.063631        -0.027421
# recoveries                                 0.968209        -0.086507
# collection_recovery_fee                    1.000000        -0.082818
# last_pymnt_amnt                           -0.082818         1.000000
# collections_12_mths_ex_med                 0.002608        -0.012855
# policy_code                                     NaN              NaN
# acc_now_delinq                             0.013489         0.007156
# tot_coll_amt                               0.001679        -0.005136
# tot_cur_bal                                0.010238         0.152009
# open_acc_6m                                0.029002         0.021802
# open_act_il                                0.005784         0.008912
# open_il_12m                                0.026995         0.039883
# open_il_24m                                0.029649         0.054411
# mths_since_rcnt_il                        -0.015116        -0.034768
# total_bal_il                               0.012982         0.044087
# il_util                                    0.015494         0.011207
# open_rv_12m                                0.023797         0.008540
# open_rv_24m                                0.029066         0.013101
# max_bal_bc                                 0.008032         0.080243
# ...
# mths_since_rcnt_il               -0.015326                   -0.219673
# total_bal_il                      0.081556                    0.793300
# il_util                          -0.081478                    0.131371
# open_rv_12m                       0.067570                   -0.016783
# open_rv_24m                       0.087254                   -0.016785
# max_bal_bc                        0.474255                    0.140634
# all_util                         -0.229742                    0.184015
# total_rev_hi_lim                  0.786690                    0.147745
# inq_fi                           -0.036108                    0.128414
# total_cu_tl                      -0.014331                    0.121289
# inq_last_12m                     -0.008390                    0.119949
# acc_open_past_24mths              0.071367                    0.186014
# avg_cur_bal                       0.128220                    0.220053
# bc_open_to_buy                    0.838426                    0.077635
# bc_util                          -0.250062                    0.019611
# chargeoff_within_12_mths         -0.015375                    0.003551
# delinq_amnt                       0.003934                   -0.000108
# mo_sin_old_il_acct                0.085758                    0.212456
# mo_sin_old_rev_tl_op              0.267420                    0.039891
# mo_sin_rcnt_rev_tl_op            -0.030768                    0.007057
# mo_sin_rcnt_tl                   -0.019716                   -0.116449
# mort_acc                          0.207567                    0.119681
# mths_since_recent_bc             -0.093078                    0.006715
# mths_since_recent_inq             0.004008                   -0.058124
# num_accts_ever_120_pd            -0.128239                    0.046733
# num_actv_bc_tl                    0.483867                    0.046232
# num_actv_rev_tl                   0.305581                    0.043225
# num_bc_sats                       0.614250                    0.059821
# num_bc_tl                         0.505532                    0.058206
# num_il_tl                         0.010180                    0.579354
# num_op_rev_tl                     0.431383                    0.058031
# num_rev_accts                     0.370778                    0.066260
# num_rev_tl_bal_gt_0               0.303523                    0.044115
# num_sats                          0.383754                    0.363515
# num_tl_120dpd_2m                 -0.000770                    0.004738
# num_tl_30dpd                      0.005391                    0.015158
# num_tl_90g_dpd_24m               -0.057908                    0.030949
# num_tl_op_past_12m                0.052165                    0.136226
# pct_tl_nvr_dlq                    0.216063                    0.018734
# percent_bc_gt_75                 -0.212211                    0.014375
# pub_rec_bankruptcies             -0.143149                   -0.035220
# tax_liens                        -0.026758                    0.003826
# tot_hi_cred_lim                   0.409531                    0.425702
# total_bal_ex_mort                 0.291439                    0.877997
# total_bc_limit                    1.000000                    0.139766
# total_il_high_credit_limit        0.139766                    1.000000
# emp_length_int                    0.063308                   -0.024182
# term_int                          0.066960                    0.088614
# mths_since_loan_issue            -0.085339                   -0.054438
# mths_since_earliest_cr            0.216930                    0.044579
# good_bad                          0.074347                    0.017123
#
#                             emp_length_int  term_int  mths_since_loan_issue  \
# loan_amnt                         0.079062  0.395166              -0.062345
# funded_amnt                       0.079115  0.394741              -0.064122
# funded_amnt_inv                   0.079559  0.395111              -0.069779
# int_rate                         -0.010826  0.376501               0.041928
# installment                       0.067219  0.141300              -0.048343
# annual_inc                        0.032903  0.024829              -0.017881
# dti                               0.014986  0.058898              -0.066462
# delinq_2yrs                       0.024464 -0.008819               0.006230
# inq_last_6mths                   -0.001192 -0.002886               0.148746
# mths_since_last_delinq           -0.005004  0.003760              -0.019905
# open_acc                          0.052086  0.074341              -0.027245
# pub_rec                           0.031650 -0.016272              -0.002045
# revol_bal                         0.086223  0.081121               0.003136
# revol_util                        0.033246  0.065168               0.162754
# total_acc                         0.103541  0.095396               0.064295
# out_prncp                         0.008561  0.287367              -0.538120
# out_prncp_inv                     0.008571  0.287440              -0.538079
# total_pymnt                       0.083986  0.209533               0.380767
# total_pymnt_inv                   0.084454  0.210062               0.375500
# total_rec_prncp                   0.075999  0.083402               0.365186
# total_rec_int                     0.071875  0.489522               0.250153
# total_rec_late_fee               -0.003499  0.022585               0.018743
# recoveries                        0.011123  0.106404               0.090920
# collection_recovery_fee           0.011041  0.100840               0.075450
# last_pymnt_amnt                   0.044328  0.142088               0.137372
# collections_12_mths_ex_med       -0.008210 -0.008813              -0.025802
# policy_code                            NaN       NaN                    NaN
# acc_now_delinq                    0.008534 -0.003754               0.015109
# tot_coll_amt                      0.003073 -0.012114              -0.005037
# tot_cur_bal                       0.097840  0.107357              -0.013032
# open_acc_6m                       0.015018 -0.000257               0.015401
# open_act_il                      -0.080189  0.032054               0.005798
# open_il_12m                       0.023763  0.025147               0.008802
# open_il_24m                       0.036097  0.043784               0.010157
# mths_since_rcnt_il               -0.012108 -0.025570               0.000978
# total_bal_il                     -0.032842  0.061014               0.000149
# il_util                          -0.071235  0.014181               0.019317
# open_rv_12m                       0.007094 -0.020919               0.015716
# open_rv_24m                       0.003934 -0.017371               0.019154
# max_bal_bc                        0.045407  0.074886              -0.001449
# all_util                         -0.040395  0.035252               0.047139
# total_rev_hi_lim                  0.089254  0.067558              -0.063676
# inq_fi                            0.004956  0.017506              -0.013130
# total_cu_tl                       0.064096  0.046015               0.000855
# inq_last_12m                     -0.006397  0.016802               0.016068
# acc_open_past_24mths              0.022705  0.028292              -0.018254
# avg_cur_bal                       0.080533  0.080081              -0.007517
# bc_open_to_buy                    0.029308  0.014434              -0.123412
# bc_util                           0.029231  0.048595               0.172370
# chargeoff_within_12_mths          0.010170 -0.001887              -0.001805
# delinq_amnt                       0.002796  0.000636               0.002393
# mo_sin_old_il_acct                0.114454  0.066850               0.020997
# mo_sin_old_rev_tl_op              0.190084  0.041735               0.025752
# mo_sin_rcnt_rev_tl_op             0.015786  0.018912              -0.024050
# mo_sin_rcnt_tl                   -0.009201 -0.005782              -0.010116
# mort_acc                          0.177564  0.102214               0.082520
# mths_since_recent_bc              0.038892  0.019143              -0.001729
# mths_since_recent_inq             0.003309 -0.012769              -0.028171
# num_accts_ever_120_pd             0.008645 -0.017395              -0.006297
# num_actv_bc_tl                    0.076251  0.050238               0.016759
# num_actv_rev_tl                   0.119747  0.053870               0.041878
# num_bc_sats                       0.070967  0.048379              -0.013880
# num_bc_tl                         0.108596  0.043619               0.114442
# num_il_tl                        -0.036787  0.075265               0.001944
# num_op_rev_tl                     0.110935  0.047619               0.008888
# num_rev_accts                     0.140155  0.047013               0.092827
# num_rev_tl_bal_gt_0               0.120956  0.054518               0.046073
# num_sats                          0.047846  0.073803               0.000395
# num_tl_120dpd_2m                  0.004131  0.000170               0.009794
# num_tl_30dpd                      0.008234 -0.003347               0.013981
# num_tl_90g_dpd_24m                0.000217 -0.011611               0.011594
# num_tl_op_past_12m                0.021581  0.007262              -0.010061
# pct_tl_nvr_dlq                   -0.019184  0.040134               0.006933
# percent_bc_gt_75                  0.027843  0.045741               0.164177
# pub_rec_bankruptcies              0.024064 -0.011910              -0.027993
# tax_liens                         0.017236 -0.005602               0.008820
# tot_hi_cred_lim                   0.113703  0.106330              -0.030871
# total_bal_ex_mort                -0.008514  0.103438              -0.036439
# total_bc_limit                    0.063308  0.066960              -0.085339
# total_il_high_credit_limit       -0.024182  0.088614              -0.054438
# emp_length_int                    1.000000  0.051557               0.010880
# term_int                          0.051557  1.000000              -0.022343
# mths_since_loan_issue             0.010880 -0.022343               1.000000
# mths_since_earliest_cr            0.202200  0.040076               0.207242
# good_bad                          0.009736 -0.084242              -0.158640
#
#                             mths_since_earliest_cr  good_bad
# loan_amnt                                 0.140995 -0.017731
# funded_amnt                               0.140677 -0.017543
# funded_amnt_inv                           0.139757 -0.016802
# int_rate                                 -0.106607 -0.201226
# installment                               0.122815 -0.023890
# annual_inc                                0.062216  0.019253
# dti                                       0.026749 -0.034686
# delinq_2yrs                               0.083288 -0.018198
# inq_last_6mths                            0.030882 -0.087549
# mths_since_last_delinq                   -0.025296  0.006796
# open_acc                                  0.139601 -0.012843
# pub_rec                                   0.059620 -0.033516
# revol_bal                                 0.215818  0.021832
# revol_util                                0.060696 -0.065547
# total_acc                                 0.286441 -0.009963
# out_prncp                                -0.066187  0.207555
# out_prncp_inv                            -0.066172  0.207535
# total_pymnt                               0.210842  0.133029
# total_pymnt_inv                           0.210079  0.133098
# total_rec_prncp                           0.207176  0.216887
# total_rec_int                             0.130986 -0.042991
# total_rec_late_fee                        0.002902 -0.097801
# recoveries                                0.021354 -0.509539
# collection_recovery_fee                   0.019684 -0.488172
# last_pymnt_amnt                           0.077239  0.177427
# collections_12_mths_ex_med               -0.001402 -0.010382
# policy_code                                    NaN       NaN
# acc_now_delinq                            0.029538 -0.008341
# tot_coll_amt                              0.029047 -0.006722
# tot_cur_bal                               0.178034  0.054978
# open_acc_6m                               0.005146 -0.047191
# open_act_il                              -0.030519 -0.001679
# open_il_12m                               0.006393 -0.037522
# open_il_24m                               0.006254 -0.036532
# mths_since_rcnt_il                        0.037342  0.020597
# total_bal_il                              0.033474  0.000198
# il_util                                  -0.051931 -0.034935
# open_rv_12m                              -0.013115 -0.044377
# open_rv_24m                              -0.030867 -0.051518
# max_bal_bc                                0.165495  0.023369
# all_util                                 -0.024824 -0.045285
# total_rev_hi_lim                          0.234693  0.058346
# inq_fi                                   -0.025428 -0.026451
# total_cu_tl                               0.040453 -0.003323
# inq_last_12m                             -0.017714 -0.047848
# acc_open_past_24mths                     -0.037292 -0.088630
# avg_cur_bal                               0.123858  0.057780
# bc_open_to_buy                            0.126214  0.080325
# bc_util                                   0.050254 -0.071227
# chargeoff_within_12_mths                  0.030682  0.000025
# delinq_amnt                               0.010669 -0.001899
# mo_sin_old_il_acct                        0.343630  0.023277
# mo_sin_old_rev_tl_op                      0.890405  0.035983
# mo_sin_rcnt_rev_tl_op                     0.063020  0.053391
# mo_sin_rcnt_tl                            0.027512  0.056157
# mort_acc                                  0.294291  0.041920
# mths_since_recent_bc                      0.111808  0.044990
# mths_since_recent_inq                    -0.004319  0.056656
# num_accts_ever_120_pd                     0.083776 -0.008531
# num_actv_bc_tl                            0.122583 -0.021465
# num_actv_rev_tl                           0.159159 -0.047433
# num_bc_sats                               0.137304 -0.001945
# num_bc_tl                                 0.281450 -0.013718
# num_il_tl                                 0.029596 -0.008255
# num_op_rev_tl                             0.170578 -0.020722
# num_rev_accts                             0.317405 -0.018755
# num_rev_tl_bal_gt_0                       0.157587 -0.047227
# num_sats                                  0.136899 -0.014188
# num_tl_120dpd_2m                          0.010200 -0.004689
# num_tl_30dpd                              0.025248 -0.003986
# num_tl_90g_dpd_24m                        0.038914 -0.010088
# num_tl_op_past_12m                       -0.012844 -0.081352
# pct_tl_nvr_dlq                           -0.093193  0.005176
# percent_bc_gt_75                          0.059379 -0.074352
# pub_rec_bankruptcies                      0.041929 -0.025795
# tax_liens                                 0.035518 -0.016196
# tot_hi_cred_lim                           0.204085  0.065703
# total_bal_ex_mort                         0.116560  0.015104
# total_bc_limit                            0.216930  0.074347
# total_il_high_credit_limit                0.044579  0.017123
# emp_length_int                            0.202200  0.009736
# term_int                                  0.040076 -0.084242
# mths_since_loan_issue                     0.207242 -0.158640
# mths_since_earliest_cr                    1.000000 -0.003235
# good_bad                                 -0.003235  1.000000

# %%
# Checking for multicollinearity

for first_column in matrix.columns:
    for second_column in matrix.columns:
        if (first_column != second_column) and (matrix[first_column][second_column] <= -0.9 or matrix[first_column][second_column] >= 0.9):
            print('{} and {} are highly correlated by {}'.format(first_column, second_column, matrix[first_column][second_column]))
# Out:
# loan_amnt and funded_amnt are highly correlated by 0.9997532435800889
# loan_amnt and funded_amnt_inv are highly correlated by 0.9990310903430786
# loan_amnt and installment are highly correlated by 0.9456203923258554
# funded_amnt and loan_amnt are highly correlated by 0.9997532435800889
# funded_amnt and funded_amnt_inv are highly correlated by 0.9993405026619953
# funded_amnt and installment are highly correlated by 0.945965377861421
# funded_amnt_inv and loan_amnt are highly correlated by 0.9990310903430786
# funded_amnt_inv and funded_amnt are highly correlated by 0.9993405026619953
# funded_amnt_inv and installment are highly correlated by 0.9451104277553494
# installment and loan_amnt are highly correlated by 0.9456203923258554
# installment and funded_amnt are highly correlated by 0.945965377861421
# installment and funded_amnt_inv are highly correlated by 0.9451104277553494
# open_acc and num_sats are highly correlated by 0.9896859559627451
# out_prncp and out_prncp_inv are highly correlated by 0.9999987779793087
# out_prncp_inv and out_prncp are highly correlated by 0.9999987779793087
# total_pymnt and total_pymnt_inv are highly correlated by 0.9993969752675592
# total_pymnt and total_rec_prncp are highly correlated by 0.9671142630928876
# total_pymnt_inv and total_pymnt are highly correlated by 0.9993969752675592
# total_pymnt_inv and total_rec_prncp are highly correlated by 0.9664771038520156
# total_rec_prncp and total_pymnt are highly correlated by 0.9671142630928876
# total_rec_prncp and total_pymnt_inv are highly correlated by 0.9664771038520156
# recoveries and collection_recovery_fee are highly correlated by 0.9682093775280732
# collection_recovery_fee and recoveries are highly correlated by 0.9682093775280732
# tot_cur_bal and tot_hi_cred_lim are highly correlated by 0.984284629927558
# num_actv_rev_tl and num_rev_tl_bal_gt_0 are highly correlated by 0.9833132990531477
# num_rev_tl_bal_gt_0 and num_actv_rev_tl are highly correlated by 0.9833132990531477
# num_sats and open_acc are highly correlated by 0.9896859559627451
# tot_hi_cred_lim and tot_cur_bal are highly correlated by 0.984284629927558

# %% [markdown]
# The following variables are highly correlated with other variables in the feature set and I hereby drop them from analysis. And there is enough data so that dropping these records should not be of too much a concern.

# %%
# Make a list multicollinear variables

correlated_vars = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment', 'num_sats', 'out_prncp', 'total_pymnt', 'total_pymnt_inv',
                   'total_rec_prncp', 'recoveries', 'tot_cur_bal', 'num_actv_rev_tl']

# %%
# Drop multicollinear variables from the analysis

selected_cont_vars = cont_sample_scaled.drop(correlated_vars, axis = 1)

# %%
# Quick view the resulting dataframe

selected_cont_vars.head()
# Out:
c_util  chargeoff_within_12_mths  delinq_amnt  \
# 0       -0.620189  1.017159                 -0.078864     -0.01813
# 1        1.164568  0.257171                 -0.078864     -0.01813
# 2       -0.466409  0.608754                 -0.078864     -0.01813
# 3        0.324420 -1.500746                 -0.078864     -0.01813
# 4       -0.592129  0.512868                 -0.078864     -0.01813
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0            0.544789             -0.739462              -0.292568
# 1            3.011209              1.162338              -0.292568
# 2           -0.476463              0.462225              -0.409116
# 3            0.063066             -1.157439               0.872921
# 4           -0.071816              0.044247               0.523275
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_inq  \
# 0       -0.032013 -0.297903              0.317378               0.171989
# 1        0.078140 -0.828083             -0.497529               1.784370
# 2       -0.142166 -0.297903              0.003952              -0.007165
# 3        0.078140  1.292636              0.129323               0.709449
# 4       -0.252319 -0.828083              0.442749              -0.186318
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 0              -0.377617       -0.732683    -0.926062  -1.020911   0.761983
# 1              -0.377617        1.891165     1.079778   0.492709   3.499749
# 2              -0.377617        0.579241     0.411165   1.790097  -0.743788
# 3              -0.377617       -0.732683    -0.591755  -0.804680   0.077541
# 4              -0.377617       -1.169991    -1.260369  -1.453374  -0.470012
#
#    num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_tl_120dpd_2m  \
# 0      -0.919355      -1.137479            -1.102347         -0.025772
# 1       0.601643       0.127234             0.750374         -0.025772
# 2       0.384358       1.139005             0.441588         -0.025772
# 3      -1.136640      -0.884536            -1.102347         -0.025772
# 4      -0.919355      -1.011008            -0.793560         -0.025772
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0      -0.05209           -0.169742            0.515969        0.660280
# 1      -0.05209           -0.169742           -0.598512        0.660280
# 2      -0.05209           -0.169742           -0.598512        0.660280
# 3      -0.05209           -0.169742            1.073209        0.099011
# 4      -0.05209           -0.169742           -0.598512        0.660280
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0          0.213412             -0.350283  -0.126898        -0.598969
# 1          0.564188             -0.350283  -0.126898        -0.048899
# 2          0.494033              2.403678  -0.126898         0.457126
# 3         -1.189689             -0.350283  -0.126898         0.008510
# 4         -1.189689             -0.350283  -0.126898        -0.696240
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0           0.070209       -0.603847                    0.222224
# 1           1.132068        3.106599                    0.557096
# 2          -0.479879       -0.352665                   -0.626479
# 3          -0.452306       -0.149956                   -0.250089
# 4          -0.238170       -0.744861                   -0.108634
#
#    emp_length_int  term_int  mths_since_loan_issue  mths_since_earliest_cr  \
# 0       -0.258713 -0.635836              -0.878214               -0.654022
# 1       -0.258713 -0.635836              -1.110473                0.766171
# 2        1.129438 -0.635836               0.701146                0.480013
# 3        1.129438 -0.635836              -0.042082               -0.728211
# 4       -0.813974  1.572733              -1.017569               -0.336068
#
#    good_bad
# 0  0.366814
# 1  0.366814
# 2  0.366814
# 3 -2.726180
# 4  0.366814

# %% [markdown]
# The remaining variables are the selected continous variables that will be used in modeling credit risk.

# %%
# Make a list of selected continous variables

cont_vars_selected = []
for column_name in selected_cont_vars:
  cont_vars_selected.append(column_name)

# %%
# List of selected continous vars

cont_vars_selected
# Out:
# ['int_rate',
#  'annual_inc',
#  'dti',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'out_prncp_inv',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'collections_12_mths_ex_med',
#  'policy_code',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'emp_length_int',
#  'term_int',
#  'mths_since_loan_issue',
#  'mths_since_earliest_cr',
#  'good_bad']

# %% [markdown]
# This concludes analysis of continous variables from the lending club dataset.
